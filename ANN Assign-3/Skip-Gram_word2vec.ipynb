# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
import random

from collections import Counter
# Out:
# C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Program Files\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
t_start = time.perf_counter()
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
# Your code here
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) 
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) 
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 2048
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6312 0.0818 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5942 0.0658 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5583 0.0674 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5916 0.0648 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5305 0.0673 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5957 0.0648 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4716 0.0647 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4190 0.0654 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3768 0.0673 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3306 0.0658 sec/batch
# Nearest to from: gardena, remind, calcutta, position, industrialisation, sentence, continuation, maroons,
# Nearest to not: placidia, zinc, ramat, jamil, defeated, schrader, memoriam, cruel,
# Nearest to will: situations, turkish, mobutu, donation, katsura, philosophiques, kathleen, pseudepigrapha,
# Nearest to had: diagnosed, dipoles, searched, under, die, lago, lenihan, rivalries,
# Nearest to world: subsequent, aggregate, eglise, qing, unintentional, inquirer, difficult, modifications,
# Nearest to some: erewhon, thermus, fsf, lennie, anyway, scalp, progs, hands,
# Nearest to this: athaliah, lyons, heapsort, persons, abydos, starck, whitman, robbe,
# Nearest to use: suitcase, slight, retained, erbia, stott, ecclesiastes, was, victor,
# Nearest to engineering: jezreel, gentis, socio, gluconeogenesis, diego, allemande, aengus, shanahan,
# Nearest to taking: pieter, cylinder, tetralogy, envisioned, canc, includes, immature, unita,
# Nearest to road: sobriquet, invulnerability, alligator, scotia, evolutionist, sla, avatar, physically,
# Nearest to hit: loopholes, renin, brasses, ministry, electing, boyne, atlantans, sfg,
# Nearest to instance: manfred, students, attended, forged, hamsters, infante, debilitating, homophobia,
# Nearest to heavy: euglenids, delta, infogrames, nagy, wands, conceptual, subatomic, ranatunga,
# Nearest to animals: mongoloid, spires, mckeon, argumentum, ee, magnifying, increments, tort,
# Nearest to san: schenectady, legislation, gesta, breaches, desmond, takes, pero, eisenhower,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1772 0.0661 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.1759 0.0671 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0667 0.0669 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.0105 0.0685 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9643 0.0670 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9114 0.0659 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8902 0.0667 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8566 0.0657 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8381 0.0658 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8241 0.0657 sec/batch
# Nearest to from: ch, humility, continuation, illustrates, protests, regulation, industrialisation, calcutta,
# Nearest to not: placidia, zinc, ramat, jamil, claim, strange, represent, memoriam,
# Nearest to will: kathleen, evolutionary, tunnels, catalog, donation, philosophiques, mashed, ratio,
# Nearest to had: diagnosed, searched, dipoles, under, lago, conquistadores, rebecca, discovered,
# Nearest to world: negotiations, qing, difficult, framework, aggregate, unintentional, eglise, circuitry,
# Nearest to some: erewhon, fsf, anyway, scalp, progs, lennie, officials, thermus,
# Nearest to this: heapsort, persisted, decides, rendered, significance, athaliah, persons, lyons,
# Nearest to use: suitcase, ecclesiastes, yalta, stott, catholicism, erbia, warn, walt,
# Nearest to engineering: jezreel, diego, entrepot, socio, gluconeogenesis, unconstitutional, permissible, gentis,
# Nearest to taking: pieter, cylinder, envisioned, tetralogy, immature, reunification, canc, medicare,
# Nearest to road: sobriquet, invulnerability, scotia, physically, politicians, alligator, sub, evolutionist,
# Nearest to hit: loopholes, ministry, boyne, electing, armenia, higher, couples, ps,
# Nearest to instance: students, manfred, homophobia, attended, forged, infante, safe, always,
# Nearest to heavy: delta, euglenids, nagy, infogrames, wands, subatomic, winner, viva,
# Nearest to animals: mongoloid, mckeon, spires, argumentum, telegrams, increments, magnifying, ee,
# Nearest to san: schenectady, legislation, takes, breaches, gesta, worthwhile, sioux, glaser,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8146 0.0661 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8056 0.0654 sec/batch
# Epoch 2/10 Iteration: 2300 Avg. Training loss: 4.8020 0.0277 sec/batch
# Epoch 2/10 Iteration: 2400 Avg. Training loss: 4.6821 0.0659 sec/batch
# Epoch 2/10 Iteration: 2500 Avg. Training loss: 4.7298 0.0661 sec/batch
# Epoch 2/10 Iteration: 2600 Avg. Training loss: 4.6946 0.0656 sec/batch
# Epoch 2/10 Iteration: 2700 Avg. Training loss: 4.7231 0.0655 sec/batch
# Epoch 2/10 Iteration: 2800 Avg. Training loss: 4.6507 0.0662 sec/batch
# Epoch 2/10 Iteration: 2900 Avg. Training loss: 4.6618 0.0656 sec/batch
# Epoch 2/10 Iteration: 3000 Avg. Training loss: 4.6185 0.0659 sec/batch
# Nearest to from: continuation, humility, gardena, henotheism, regulation, ch, neurology, solo,
# Nearest to not: placidia, ramat, zinc, jamil, represent, lastly, claim, memoriam,
# Nearest to will: mashed, sugars, evolutionary, situations, donation, philosophiques, katsura, derivatives,
# Nearest to had: diagnosed, searched, dipoles, conquistadores, lago, rebecca, lenihan, under,
# Nearest to world: qing, alu, negotiations, western, circuitry, eglise, wrestler, framework,
# Nearest to some: erewhon, fsf, characterisation, scalp, lennie, anyway, progs, decreases,
# Nearest to this: persisted, heapsort, athaliah, hunts, abydos, robbe, subtly, hospitalization,
# Nearest to use: suitcase, ecclesiastes, stott, warn, dismayed, sailboat, yalta, erbia,
# Nearest to engineering: gluconeogenesis, diego, permissible, gentis, jezreel, ext, unconstitutional, bahama,
# Nearest to taking: pieter, cylinder, tetralogy, envisioned, immature, canc, medicare, reunification,
# Nearest to road: sobriquet, scotia, invulnerability, politicians, evolutionist, alligator, subdominant, chloroform,
# Nearest to hit: loopholes, electing, brasses, ministry, specialising, allegorically, boyne, atlantans,
# Nearest to instance: students, forged, homophobia, safe, consider, always, manfred, nodes,
# Nearest to heavy: euglenids, infogrames, wands, nagy, delta, subatomic, renderings, satsuki,
# Nearest to animals: mongoloid, spires, primates, argumentum, magnifying, increments, sideways, cerf,
# Nearest to san: schenectady, gesta, sioux, pero, breaches, legislation, teamed, worthwhile,
# Epoch 2/10 Iteration: 3100 Avg. Training loss: 4.6113 0.0660 sec/batch
# Epoch 2/10 Iteration: 3200 Avg. Training loss: 4.6287 0.0650 sec/batch
# Epoch 2/10 Iteration: 3300 Avg. Training loss: 4.5742 0.0653 sec/batch
# Epoch 2/10 Iteration: 3400 Avg. Training loss: 4.5929 0.0649 sec/batch
# Epoch 2/10 Iteration: 3500 Avg. Training loss: 4.5863 0.0649 sec/batch
# Epoch 2/10 Iteration: 3600 Avg. Training loss: 4.5466 0.0649 sec/batch
# Epoch 2/10 Iteration: 3700 Avg. Training loss: 4.5752 0.0653 sec/batch
# Epoch 2/10 Iteration: 3800 Avg. Training loss: 4.6177 0.0650 sec/batch
# Epoch 2/10 Iteration: 3900 Avg. Training loss: 4.5426 0.0653 sec/batch
# Epoch 2/10 Iteration: 4000 Avg. Training loss: 4.5293 0.0661 sec/batch
# Nearest to from: continuation, humility, neurology, henotheism, gardena, regulation, calcutta, pedersen,
# Nearest to not: claim, any, lastly, represent, ramat, jamil, zinc, define,
# Nearest to will: mashed, evolutionary, sugars, situations, overlooked, pantheons, katsura, derivatives,
# Nearest to had: diagnosed, searched, conquistadores, dipoles, under, lago, waal, dungy,
# Nearest to world: qing, negotiations, western, alu, leahy, subsequent, hashim, eglise,
# Nearest to some: erewhon, fsf, lennie, anyway, scalp, progs, characterisation, litigious,
# Nearest to this: persisted, heapsort, athaliah, hunts, rendered, abydos, symbols, distinctions,
# Nearest to use: suitcase, ecclesiastes, stott, warn, dismayed, sailboat, atoms, smear,
# Nearest to engineering: gluconeogenesis, ext, high, diego, gentis, permissible, microsoft, jezreel,
# Nearest to taking: pieter, tetralogy, cylinder, immature, envisioned, canc, medicare, schechter,
# Nearest to road: scotia, sobriquet, evolutionist, chloroform, alligator, invulnerability, subdominant, politicians,
# Nearest to hit: brasses, allegorically, loopholes, ministry, electing, atlantans, specialising, renin,
# Nearest to instance: consider, forged, students, nodes, always, homophobia, safe, inaccurately,
# Nearest to heavy: euglenids, infogrames, wands, subatomic, renderings, cost, presumes, satsuki,
# Nearest to animals: mongoloid, primates, spires, argumentum, magnifying, increments, variation, decaying,
# Nearest to san: schenectady, pero, sioux, gesta, teamed, desmond, yesterday, miranda,
# Epoch 2/10 Iteration: 4100 Avg. Training loss: 4.5919 0.0663 sec/batch
# Epoch 2/10 Iteration: 4200 Avg. Training loss: 4.5434 0.0655 sec/batch
# Epoch 2/10 Iteration: 4300 Avg. Training loss: 4.5037 0.0645 sec/batch
# Epoch 2/10 Iteration: 4400 Avg. Training loss: 4.4903 0.0648 sec/batch
# Epoch 2/10 Iteration: 4500 Avg. Training loss: 4.5114 0.0645 sec/batch
# Epoch 3/10 Iteration: 4600 Avg. Training loss: 4.4974 0.0548 sec/batch
# Epoch 3/10 Iteration: 4700 Avg. Training loss: 4.4481 0.0656 sec/batch
# Epoch 3/10 Iteration: 4800 Avg. Training loss: 4.4414 0.0650 sec/batch
# Epoch 3/10 Iteration: 4900 Avg. Training loss: 4.4721 0.0645 sec/batch
# Epoch 3/10 Iteration: 5000 Avg. Training loss: 4.4034 0.0649 sec/batch
# Nearest to from: continuation, neurology, humility, soa, henotheism, crooked, pedersen, gardena,
# Nearest to not: claim, encapsulating, thc, forceful, placidia, any, lastly, jamil,
# Nearest to will: mashed, overlooked, situations, watchman, evolutionary, sugars, katsura, pantheons,
# Nearest to had: diagnosed, waal, conquistadores, searched, under, bonfires, lenihan, rebecca,
# Nearest to world: negotiations, qing, western, furrows, subsequent, alu, hashim, republic,
# Nearest to some: erewhon, fsf, wealth, scalp, progs, anyway, hopewell, lennie,
# Nearest to this: athaliah, persisted, symbols, heapsort, rendered, pre, come, hunts,
# Nearest to use: suitcase, ecclesiastes, warn, stott, smear, dismayed, sailboat, cable,
# Nearest to engineering: gluconeogenesis, ext, high, gentis, microsoft, aqueous, lagonda, layered,
# Nearest to taking: tetralogy, pieter, cylinder, canc, envisioned, immature, protagonists, gained,
# Nearest to road: scotia, sobriquet, areal, evolutionist, subdominant, chloroform, cloth, invulnerability,
# Nearest to hit: allegorically, brasses, score, electing, wedding, atlantans, specialising, ministry,
# Nearest to instance: consider, nodes, homophobia, students, always, forged, locomotion, debilitating,
# Nearest to heavy: euglenids, infogrames, wands, cost, satsuki, renderings, maui, revolutionized,
# Nearest to animals: primates, mongoloid, spires, increments, argumentum, food, sorghum, magnifying,
# Nearest to san: schenectady, pero, sioux, teamed, gesta, ducks, miranda, yesterday,
# Epoch 3/10 Iteration: 5100 Avg. Training loss: 4.3965 0.0654 sec/batch
# Epoch 3/10 Iteration: 5200 Avg. Training loss: 4.3627 0.0649 sec/batch
# Epoch 3/10 Iteration: 5300 Avg. Training loss: 4.4036 0.0650 sec/batch
# Epoch 3/10 Iteration: 5400 Avg. Training loss: 4.3610 0.0653 sec/batch
# Epoch 3/10 Iteration: 5500 Avg. Training loss: 4.3932 0.0691 sec/batch
# Epoch 3/10 Iteration: 5600 Avg. Training loss: 4.3740 0.0650 sec/batch
# Epoch 3/10 Iteration: 5700 Avg. Training loss: 4.3610 0.0651 sec/batch
# Epoch 3/10 Iteration: 5800 Avg. Training loss: 4.3470 0.0647 sec/batch
# Epoch 3/10 Iteration: 5900 Avg. Training loss: 4.3427 0.0654 sec/batch
# Epoch 3/10 Iteration: 6000 Avg. Training loss: 4.4014 0.0650 sec/batch
# Nearest to from: continuation, soa, neurology, pedersen, occlusion, crooked, humility, triadic,
# Nearest to not: encapsulating, claim, lastly, any, placidia, backdoor, stitching, cruel,
# Nearest to will: mashed, situations, overlooked, katsura, watchman, sugars, assuming, evolutionary,
# Nearest to had: diagnosed, conquistadores, bonfires, searched, waal, lenihan, under, foretell,
# Nearest to world: negotiations, qing, hashim, western, subsequent, alu, republic, furrows,
# Nearest to some: fsf, wealth, lennie, hopewell, scalp, progs, anyway, erewhon,
# Nearest to this: persisted, athaliah, heapsort, rendered, symbols, decides, puts, pre,
# Nearest to use: suitcase, stott, warn, ecclesiastes, encryption, cable, recreations, strictly,
# Nearest to engineering: gluconeogenesis, ext, high, microsoft, layered, aqueous, interacts, lagonda,
# Nearest to taking: tetralogy, pieter, cylinder, envisioned, canc, immature, parable, gained,
# Nearest to road: scotia, sobriquet, victoria, areal, gardens, kamon, lough, subdominant,
# Nearest to hit: score, allegorically, brasses, owner, wedding, atlantans, specialising, aces,
# Nearest to instance: consider, nodes, forged, plurals, always, locomotion, students, demetrius,
# Nearest to heavy: euglenids, infogrames, cost, wands, satsuki, maui, bolt, revolutionized,
# Nearest to animals: primates, mongoloid, sorghum, food, spires, argumentum, increments, decaying,
# Nearest to san: schenectady, sioux, pero, gesta, teamed, yesterday, delgado, ducks,
# Epoch 3/10 Iteration: 6100 Avg. Training loss: 4.3629 0.0663 sec/batch
# Epoch 3/10 Iteration: 6200 Avg. Training loss: 4.3680 0.0651 sec/batch
# Epoch 3/10 Iteration: 6300 Avg. Training loss: 4.3409 0.0656 sec/batch
# Epoch 3/10 Iteration: 6400 Avg. Training loss: 4.3956 0.0652 sec/batch
# Epoch 3/10 Iteration: 6500 Avg. Training loss: 4.3093 0.0651 sec/batch
# Epoch 3/10 Iteration: 6600 Avg. Training loss: 4.3137 0.0654 sec/batch
# Epoch 3/10 Iteration: 6700 Avg. Training loss: 4.3029 0.0653 sec/batch
# Epoch 4/10 Iteration: 6800 Avg. Training loss: 4.3260 0.0171 sec/batch
# Epoch 4/10 Iteration: 6900 Avg. Training loss: 4.3001 0.0650 sec/batch
# Epoch 4/10 Iteration: 7000 Avg. Training loss: 4.2371 0.0648 sec/batch
# Nearest to from: continuation, occlusion, neurology, soa, crooked, humility, triadic, liberate,
# Nearest to not: encapsulating, claim, cruel, placidia, lastly, any, backdoor, represent,
# Nearest to will: mashed, situations, katsura, watchman, assuming, overlooked, pantheons, smg,
# Nearest to had: diagnosed, conquistadores, bonfires, searched, under, waal, lenihan, reassert,
# Nearest to world: negotiations, subsequent, western, qing, furrows, republic, hashim, framework,
# Nearest to some: fsf, lennie, hopewell, scalp, anyway, progs, prohibit, wealth,
# Nearest to this: persisted, heapsort, rendered, decides, athaliah, symbols, puts, pre,
# Nearest to use: suitcase, warn, stott, cable, ecclesiastes, sailboat, encryption, recreations,
# Nearest to engineering: gluconeogenesis, ext, aqueous, layered, microsoft, high, interacts, lagonda,
# Nearest to taking: tetralogy, cylinder, pieter, envisioned, canc, immature, gained, parable,
# Nearest to road: scotia, areal, victoria, gardens, lough, invulnerability, expressways, subdominant,
# Nearest to hit: score, brasses, allegorically, owner, funny, wedding, aces, atlantans,
# Nearest to instance: consider, forged, plurals, nodes, students, parsed, follows, locomotion,
# Nearest to heavy: euglenids, reconnaissance, cost, infogrames, tank, maui, bolt, wands,
# Nearest to animals: primates, mongoloid, spires, sorghum, food, argumentum, rinsing, increments,
# Nearest to san: schenectady, pero, sioux, ducks, gesta, teamed, delgado, yesterday,
# Epoch 4/10 Iteration: 7100 Avg. Training loss: 4.2398 0.0657 sec/batch
# Epoch 4/10 Iteration: 7200 Avg. Training loss: 4.2871 0.0648 sec/batch
# Epoch 4/10 Iteration: 7300 Avg. Training loss: 4.2575 0.0650 sec/batch
# Epoch 4/10 Iteration: 7400 Avg. Training loss: 4.1972 0.0649 sec/batch
# Epoch 4/10 Iteration: 7500 Avg. Training loss: 4.2133 0.0645 sec/batch
# Epoch 4/10 Iteration: 7600 Avg. Training loss: 4.2478 0.0647 sec/batch
# Epoch 4/10 Iteration: 7700 Avg. Training loss: 4.2416 0.0645 sec/batch
# Epoch 4/10 Iteration: 7800 Avg. Training loss: 4.2399 0.0649 sec/batch
# Epoch 4/10 Iteration: 7900 Avg. Training loss: 4.2107 0.0649 sec/batch
# Epoch 4/10 Iteration: 8000 Avg. Training loss: 4.2374 0.0647 sec/batch
# Nearest to from: continuation, occlusion, neurology, crooked, troad, sutta, ziyad, soa,
# Nearest to not: encapsulating, cruel, represent, placidia, lastly, claim, backdoor, any,
# Nearest to will: mashed, situations, assuming, katsura, watchman, accountable, pantheons, overlooked,
# Nearest to had: diagnosed, conquistadores, bonfires, searched, chroniclers, waal, lenihan, under,
# Nearest to world: hashim, framework, qing, western, subsequent, intake, dresden, institutionalized,
# Nearest to some: fsf, lennie, hopewell, anyway, prohibit, progs, scalp, gathering,
# Nearest to this: persisted, rendered, heapsort, symbols, pre, decides, puts, athaliah,
# Nearest to use: suitcase, stott, warn, encryption, cable, recreations, strictly, buffers,
# Nearest to engineering: gluconeogenesis, ext, microsoft, aqueous, high, cmb, interacts, layered,
# Nearest to taking: tetralogy, envisioned, cylinder, pieter, immature, canc, innocuous, gained,
# Nearest to road: scotia, areal, lough, victoria, gardens, lights, sobriquet, railway,
# Nearest to hit: score, brasses, allegorically, funny, aces, owner, singles, wedding,
# Nearest to instance: consider, forged, nodes, plurals, follows, basis, parsed, iir,
# Nearest to heavy: euglenids, tank, reconnaissance, infogrames, cost, pips, bolt, armour,
# Nearest to animals: primates, sorghum, food, mongoloid, argumentum, spires, rinsing, decaying,
# Nearest to san: schenectady, sioux, pero, delgado, gesta, ducks, capt, yesterday,
# Epoch 4/10 Iteration: 8100 Avg. Training loss: 4.2087 0.0657 sec/batch
# Epoch 4/10 Iteration: 8200 Avg. Training loss: 4.2063 0.0650 sec/batch
# Epoch 4/10 Iteration: 8300 Avg. Training loss: 4.2213 0.0650 sec/batch
# Epoch 4/10 Iteration: 8400 Avg. Training loss: 4.1872 0.0648 sec/batch
# Epoch 4/10 Iteration: 8500 Avg. Training loss: 4.2301 0.0651 sec/batch
# Epoch 4/10 Iteration: 8600 Avg. Training loss: 4.2470 0.0651 sec/batch
# Epoch 4/10 Iteration: 8700 Avg. Training loss: 4.2400 0.0648 sec/batch
# Epoch 4/10 Iteration: 8800 Avg. Training loss: 4.1593 0.0644 sec/batch
# Epoch 4/10 Iteration: 8900 Avg. Training loss: 4.1278 0.0657 sec/batch
# Epoch 4/10 Iteration: 9000 Avg. Training loss: 4.1687 0.0649 sec/batch
# Nearest to from: continuation, occlusion, neurology, troad, redstone, crooked, sutta, liberate,
# Nearest to not: encapsulating, lastly, backdoor, represent, placidia, cruel, any, lachish,
# Nearest to will: situations, mashed, assuming, katsura, watchman, accountable, chagi, mobutu,
# Nearest to had: diagnosed, bonfires, reassert, searched, conquistadores, chroniclers, lenihan, auburn,
# Nearest to world: hashim, republic, western, protesting, qing, framework, negotiations, dresden,
# Nearest to some: fsf, hopewell, progs, prohibit, anyway, lennie, characterisation, gathering,
# Nearest to this: rendered, symbols, persisted, heapsort, decides, pre, puts, qualitatively,
# Nearest to use: suitcase, stott, cable, sailboat, encryption, strictly, recreations, warn,
# Nearest to engineering: gluconeogenesis, ext, microsoft, graduated, interacts, cmb, aqueous, layered,
# Nearest to taking: tetralogy, envisioned, cylinder, pieter, immature, gained, canc, parable,
# Nearest to road: scotia, expressways, lough, gardens, areal, railway, suburb, victoria,
# Nearest to hit: brasses, score, funny, allegorically, aces, unreleased, singles, owner,
# Nearest to instance: consider, forged, nodes, plurals, parsed, follows, decrypts, basis,
# Nearest to heavy: euglenids, tank, reconnaissance, infogrames, pips, bolt, cost, freeze,
# Nearest to animals: primates, sorghum, mongoloid, argumentum, spires, food, rinsing, hunting,
# Nearest to san: schenectady, sioux, pero, ducks, delgado, gesta, capt, teamed,
# Epoch 5/10 Iteration: 9100 Avg. Training loss: 4.2587 0.0445 sec/batch
# Epoch 5/10 Iteration: 9200 Avg. Training loss: 4.1392 0.0653 sec/batch
# Epoch 5/10 Iteration: 9300 Avg. Training loss: 4.1455 0.0654 sec/batch
# Epoch 5/10 Iteration: 9400 Avg. Training loss: 4.1071 0.0653 sec/batch
# Epoch 5/10 Iteration: 9500 Avg. Training loss: 4.1838 0.0666 sec/batch
# Epoch 5/10 Iteration: 9600 Avg. Training loss: 4.1244 0.0653 sec/batch
# Epoch 5/10 Iteration: 9700 Avg. Training loss: 4.1139 0.0654 sec/batch
# Epoch 5/10 Iteration: 9800 Avg. Training loss: 4.0834 0.0661 sec/batch
# Epoch 5/10 Iteration: 9900 Avg. Training loss: 4.1197 0.0656 sec/batch
# Epoch 5/10 Iteration: 10000 Avg. Training loss: 4.1666 0.0656 sec/batch
# Nearest to from: continuation, neurology, occlusion, troad, regulation, crooked, triadic, sutta,
# Nearest to not: encapsulating, represent, backdoor, lastly, stitching, cruel, elamite, injustice,
# Nearest to will: situations, mashed, assuming, accountable, katsura, watchman, mobutu, granada,
# Nearest to had: diagnosed, bonfires, chroniclers, searched, reassert, foretell, conquistadores, auburn,
# Nearest to world: hashim, champions, framework, western, intake, punctuated, ceilings, dresden,
# Nearest to some: fsf, hopewell, prohibit, progs, gathering, lennie, anyway, scalp,
# Nearest to this: persisted, heapsort, rendered, symbols, qualitatively, decides, pre, selectivity,
# Nearest to use: suitcase, stott, warn, cable, strictly, angina, recreations, encryption,
# Nearest to engineering: gluconeogenesis, ext, graduated, magnetometer, cmb, microsoft, interacts, aqueous,
# Nearest to taking: tetralogy, envisioned, cylinder, gained, canc, immature, help, pieter,
# Nearest to road: scotia, expressways, lough, gardens, suburb, areal, victoria, kamon,
# Nearest to hit: score, brasses, funny, allegorically, let, singles, unreleased, owner,
# Nearest to instance: consider, forged, nodes, plurals, follows, decrypts, parsed, basis,
# Nearest to heavy: euglenids, reconnaissance, tank, pips, freeze, infogrames, marmalade, armour,
# Nearest to animals: primates, argumentum, mongoloid, sorghum, food, spires, rinsing, hunting,
# Nearest to san: sioux, schenectady, pero, delgado, diego, ducks, tucson, imlay,
# Epoch 5/10 Iteration: 10100 Avg. Training loss: 4.1076 0.0659 sec/batch
# Epoch 5/10 Iteration: 10200 Avg. Training loss: 4.1350 0.0651 sec/batch
# Epoch 5/10 Iteration: 10300 Avg. Training loss: 4.1275 0.0649 sec/batch
# Epoch 5/10 Iteration: 10400 Avg. Training loss: 4.1449 0.0648 sec/batch
# Epoch 5/10 Iteration: 10500 Avg. Training loss: 4.1650 0.0651 sec/batch
# Epoch 5/10 Iteration: 10600 Avg. Training loss: 4.1340 0.0651 sec/batch
# Epoch 5/10 Iteration: 10700 Avg. Training loss: 4.0826 0.0649 sec/batch
# Epoch 5/10 Iteration: 10800 Avg. Training loss: 4.1355 0.0654 sec/batch
# Epoch 5/10 Iteration: 10900 Avg. Training loss: 4.1750 0.0649 sec/batch
# Epoch 5/10 Iteration: 11000 Avg. Training loss: 4.1078 0.0646 sec/batch
# Nearest to from: continuation, regulation, occlusion, troad, sutta, neurology, reconsolidation, ziyad,
# Nearest to not: represent, lastly, placidia, injustice, cruel, lachish, backdoor, encapsulating,
# Nearest to will: situations, mashed, watchman, assuming, accountable, katsura, quantifiable, render,
# Nearest to had: diagnosed, chroniclers, under, reassert, bonfires, conquistadores, waal, dungy,
# Nearest to world: hashim, western, institutionalized, dresden, framework, champions, protesting, republic,
# Nearest to some: fsf, lennie, hopewell, progs, armenian, conjoined, gathering, anyway,
# Nearest to this: rendered, qualitatively, persisted, decides, symbols, heapsort, pre, hawala,
# Nearest to use: suitcase, stott, cable, buffers, recreations, strictly, sailboat, angina,
# Nearest to engineering: gluconeogenesis, graduated, ext, magnetometer, microsoft, cmb, lis, interacts,
# Nearest to taking: tetralogy, envisioned, help, immature, cylinder, canc, gained, lempira,
# Nearest to road: expressways, scotia, lough, areal, gardens, railway, victoria, flagging,
# Nearest to hit: brasses, funny, score, unreleased, singles, allegorically, let, otello,
# Nearest to instance: consider, forged, plurals, decrypts, follows, nodes, parsed, does,
# Nearest to heavy: euglenids, pips, reconnaissance, tank, amur, marmalade, freeze, silks,
# Nearest to animals: primates, sorghum, mongoloid, argumentum, food, rinsing, spires, decaying,
# Nearest to san: schenectady, sioux, diego, pero, delgado, ducks, tucson, capt,
# Epoch 5/10 Iteration: 11100 Avg. Training loss: 4.0771 0.0659 sec/batch
# Epoch 5/10 Iteration: 11200 Avg. Training loss: 4.1380 0.0649 sec/batch
# Epoch 6/10 Iteration: 11300 Avg. Training loss: 4.1144 0.0067 sec/batch
# Epoch 6/10 Iteration: 11400 Avg. Training loss: 4.0448 0.0648 sec/batch
# Epoch 6/10 Iteration: 11500 Avg. Training loss: 4.0985 0.0650 sec/batch
# Epoch 6/10 Iteration: 11600 Avg. Training loss: 4.0736 0.0648 sec/batch
# Epoch 6/10 Iteration: 11700 Avg. Training loss: 4.0312 0.0649 sec/batch
# Epoch 6/10 Iteration: 11800 Avg. Training loss: 4.1299 0.0649 sec/batch
# Epoch 6/10 Iteration: 11900 Avg. Training loss: 4.0166 0.0652 sec/batch
# Epoch 6/10 Iteration: 12000 Avg. Training loss: 4.0410 0.0647 sec/batch
# Nearest to from: continuation, troad, regulation, neurology, reconsolidation, sutta, occlusion, ternary,
# Nearest to not: represent, lastly, injustice, cruel, placidia, usage, encapsulating, backdoor,
# Nearest to will: situations, mashed, watchman, assuming, accountable, smg, granada, contents,
# Nearest to had: diagnosed, chroniclers, waal, reassert, under, dungy, lenihan, foretell,
# Nearest to world: hashim, champions, western, institutionalized, framework, dresden, market, punctuated,
# Nearest to some: hopewell, armenian, progs, fsf, ncv, heathen, geophysical, conjoined,
# Nearest to this: rendered, persisted, qualitatively, decides, heapsort, pre, hawala, a,
# Nearest to use: suitcase, stott, warn, unvoiced, strictly, angina, marks, cable,
# Nearest to engineering: graduated, gluconeogenesis, ext, magnetometer, sciences, cmb, anthropology, lis,
# Nearest to taking: tetralogy, envisioned, canc, help, immature, lempira, parable, cylinder,
# Nearest to road: expressways, scotia, lough, railway, gardens, victoria, rail, flagging,
# Nearest to hit: brasses, funny, score, unreleased, hitter, allegorically, let, tackling,
# Nearest to instance: consider, forged, plurals, follows, decrypts, demetrius, parsed, nodes,
# Nearest to heavy: euglenids, reconnaissance, pips, tank, amur, silks, marmalade, abidjan,
# Nearest to animals: primates, argumentum, sorghum, mongoloid, food, rinsing, spires, suborder,
# Nearest to san: sioux, schenectady, diego, pero, delgado, tucson, ducks, imlay,
# Epoch 6/10 Iteration: 12100 Avg. Training loss: 4.0738 0.0658 sec/batch
# Epoch 6/10 Iteration: 12200 Avg. Training loss: 4.0538 0.0649 sec/batch
# Epoch 6/10 Iteration: 12300 Avg. Training loss: 4.0754 0.0650 sec/batch
# Epoch 6/10 Iteration: 12400 Avg. Training loss: 4.0505 0.0649 sec/batch
# Epoch 6/10 Iteration: 12500 Avg. Training loss: 4.0777 0.0648 sec/batch
# Epoch 6/10 Iteration: 12600 Avg. Training loss: 4.0968 0.0651 sec/batch
# Epoch 6/10 Iteration: 12700 Avg. Training loss: 4.0401 0.0649 sec/batch
# Epoch 6/10 Iteration: 12800 Avg. Training loss: 4.0588 0.0651 sec/batch
# Epoch 6/10 Iteration: 12900 Avg. Training loss: 4.0211 0.0651 sec/batch
# Epoch 6/10 Iteration: 13000 Avg. Training loss: 4.0753 0.0651 sec/batch
# Nearest to from: continuation, regulation, of, troad, reconsolidation, sutta, ternary, ziyad,
# Nearest to not: represent, lachish, usage, backdoor, injustice, elamite, any, placidia,
# Nearest to will: situations, assuming, mashed, contents, smg, accountable, watchman, expected,
# Nearest to had: reassert, diagnosed, under, was, chroniclers, foretell, his, after,
# Nearest to world: hashim, framework, champions, western, protesting, institutionalized, dresden, thinkers,
# Nearest to some: conjoined, derogatory, armenian, ncv, heathen, fsf, progs, gathering,
# Nearest to this: qualitatively, rendered, persisted, a, pre, heapsort, abydos, symbols,
# Nearest to use: suitcase, stott, unvoiced, strictly, angina, buffers, recreations, marks,
# Nearest to engineering: graduated, gluconeogenesis, ext, magnetometer, sciences, interacts, anthropology, cmb,
# Nearest to taking: tetralogy, envisioned, help, parable, csicop, immature, canc, lempira,
# Nearest to road: expressways, lough, railway, scotia, rail, syriacs, flagging, gardens,
# Nearest to hit: brasses, funny, score, unreleased, hitter, singles, otello, allegorically,
# Nearest to instance: consider, forged, plurals, decrypts, follows, rmb, dexterity, demetrius,
# Nearest to heavy: pips, euglenids, reconnaissance, tank, amur, marmalade, abidjan, silks,
# Nearest to animals: primates, argumentum, sorghum, mongoloid, rinsing, food, suborder, hunting,
# Nearest to san: sioux, schenectady, diego, delgado, pero, imlay, tucson, ducks,
# Epoch 6/10 Iteration: 13100 Avg. Training loss: 4.0890 0.0661 sec/batch
# Epoch 6/10 Iteration: 13200 Avg. Training loss: 4.0832 0.0648 sec/batch
# Epoch 6/10 Iteration: 13300 Avg. Training loss: 4.0377 0.0647 sec/batch
# Epoch 6/10 Iteration: 13400 Avg. Training loss: 4.0163 0.0650 sec/batch
# Epoch 6/10 Iteration: 13500 Avg. Training loss: 4.0627 0.0650 sec/batch
# Epoch 7/10 Iteration: 13600 Avg. Training loss: 4.0436 0.0340 sec/batch
# Epoch 7/10 Iteration: 13700 Avg. Training loss: 4.0058 0.0652 sec/batch
# Epoch 7/10 Iteration: 13800 Avg. Training loss: 4.0078 0.0650 sec/batch
# Epoch 7/10 Iteration: 13900 Avg. Training loss: 3.9822 0.0650 sec/batch
# Epoch 7/10 Iteration: 14000 Avg. Training loss: 4.0235 0.0649 sec/batch
# Nearest to from: continuation, troad, regulation, of, ternary, sulfate, reconsolidation, ziyad,
# Nearest to not: lachish, represent, injustice, placidia, any, claim, cruel, mabuse,
# Nearest to will: situations, assuming, expected, smg, watchman, contents, hajj, render,
# Nearest to had: diagnosed, was, reassert, foretell, under, valens, his, chroniclers,
# Nearest to world: champions, hashim, chaffee, protesting, dresden, framework, western, institutionalized,
# Nearest to some: conjoined, derogatory, hopewell, armenian, ncv, hands, heathen, fsf,
# Nearest to this: qualitatively, rendered, persisted, a, abydos, heapsort, pre, puts,
# Nearest to use: suitcase, angina, strictly, warn, buffers, stott, unvoiced, recreations,
# Nearest to engineering: graduated, magnetometer, gluconeogenesis, ext, sciences, interacts, campus, anthropology,
# Nearest to taking: tetralogy, envisioned, help, csicop, canc, lempira, parable, inflows,
# Nearest to road: expressways, lough, scotia, syriacs, railway, flagging, rail, gardens,
# Nearest to hit: brasses, funny, score, hitter, singles, unreleased, let, allegorically,
# Nearest to instance: consider, forged, decrypts, follows, plurals, demetrius, dexterity, subregions,
# Nearest to heavy: pips, euglenids, reconnaissance, tank, marmalade, amur, abidjan, silks,
# Nearest to animals: primates, food, argumentum, sorghum, mongoloid, suborder, rinsing, arthropod,
# Nearest to san: sioux, schenectady, diego, delgado, pero, tucson, imlay, ducks,
# Epoch 7/10 Iteration: 14100 Avg. Training loss: 4.0012 0.0660 sec/batch
# Epoch 7/10 Iteration: 14200 Avg. Training loss: 3.9947 0.0651 sec/batch
# Epoch 7/10 Iteration: 14300 Avg. Training loss: 3.9842 0.0648 sec/batch
# Epoch 7/10 Iteration: 14400 Avg. Training loss: 4.0267 0.0650 sec/batch
# Epoch 7/10 Iteration: 14500 Avg. Training loss: 4.0190 0.0649 sec/batch
# Epoch 7/10 Iteration: 14600 Avg. Training loss: 3.9853 0.0651 sec/batch
# Epoch 7/10 Iteration: 14700 Avg. Training loss: 4.0336 0.0649 sec/batch
# Epoch 7/10 Iteration: 14800 Avg. Training loss: 4.0146 0.0650 sec/batch
# Epoch 7/10 Iteration: 14900 Avg. Training loss: 3.9928 0.0649 sec/batch
# Epoch 7/10 Iteration: 15000 Avg. Training loss: 4.0030 0.0651 sec/batch
# Nearest to from: continuation, troad, of, regulation, ternary, half, remarque, pedersen,
# Nearest to not: lachish, represent, elamite, injustice, usage, stitching, lastly, claim,
# Nearest to will: situations, expected, assuming, contents, hajj, smg, watchman, mashed,
# Nearest to had: was, diagnosed, reassert, foretell, after, his, under, chroniclers,
# Nearest to world: champions, hashim, framework, critique, thinkers, protesting, institutionalized, struggles,
# Nearest to some: ncv, derogatory, conjoined, heathen, armenian, bishop, hands, hopewell,
# Nearest to this: qualitatively, a, rendered, heapsort, abydos, pre, persisted, calendars,
# Nearest to use: suitcase, strictly, stott, unvoiced, recreations, nokia, antecedent, marks,
# Nearest to engineering: graduated, gluconeogenesis, magnetometer, interacts, ext, sciences, campus, anthropology,
# Nearest to taking: envisioned, tetralogy, help, inflows, parable, students, lempira, gained,
# Nearest to road: expressways, lough, syriacs, railway, scotia, rail, flagging, routes,
# Nearest to hit: brasses, funny, singles, hitter, score, unreleased, allegorically, aphex,
# Nearest to instance: consider, forged, follows, decrypts, demetrius, plurals, dexterity, subregions,
# Nearest to heavy: pips, euglenids, reconnaissance, amur, marmalade, tank, silks, ssbauer,
# Nearest to animals: primates, suborder, food, argumentum, sorghum, mongoloid, rinsing, explorers,
# Nearest to san: sioux, diego, schenectady, delgado, pero, imlay, tucson, ducks,
# Epoch 7/10 Iteration: 15100 Avg. Training loss: 4.0086 0.0658 sec/batch
# Epoch 7/10 Iteration: 15200 Avg. Training loss: 4.0003 0.0647 sec/batch
# Epoch 7/10 Iteration: 15300 Avg. Training loss: 4.0012 0.0650 sec/batch
# Epoch 7/10 Iteration: 15400 Avg. Training loss: 4.0481 0.0649 sec/batch
# Epoch 7/10 Iteration: 15500 Avg. Training loss: 3.9907 0.0648 sec/batch
# Epoch 7/10 Iteration: 15600 Avg. Training loss: 3.9432 0.0645 sec/batch
# Epoch 7/10 Iteration: 15700 Avg. Training loss: 4.0182 0.0650 sec/batch
# Epoch 7/10 Iteration: 15800 Avg. Training loss: 4.0054 0.0654 sec/batch
# Epoch 8/10 Iteration: 15900 Avg. Training loss: 4.0027 0.0616 sec/batch
# Epoch 8/10 Iteration: 16000 Avg. Training loss: 3.9913 0.0649 sec/batch
# Nearest to from: of, troad, continuation, half, regulation, sulfate, ternary, becoming,
# Nearest to not: injustice, lachish, usage, stitching, represent, any, anointed, forwarded,
# Nearest to will: situations, expected, watchman, hajj, assuming, contents, roundaboutness, smg,
# Nearest to had: was, diagnosed, reassert, after, under, foretell, amazons, his,
# Nearest to world: champions, hashim, framework, thinkers, critique, protesting, dresden, western,
# Nearest to some: ncv, derogatory, hopewell, conjoined, armenian, hands, heathen, cases,
# Nearest to this: qualitatively, a, heapsort, pre, calendars, abydos, puts, symbols,
# Nearest to use: suitcase, unvoiced, strictly, angina, buffers, marks, nokia, antecedent,
# Nearest to engineering: graduated, magnetometer, gluconeogenesis, campus, interacts, aerospace, sciences, ext,
# Nearest to taking: envisioned, tetralogy, help, inflows, parable, lempira, students, csicop,
# Nearest to road: expressways, lough, syriacs, railway, rail, traffic, flagging, gardens,
# Nearest to hit: brasses, funny, singles, hitter, unreleased, score, pmrc, armenia,
# Nearest to instance: consider, forged, dexterity, follows, subregions, decrypts, cashier, rmb,
# Nearest to heavy: pips, euglenids, reconnaissance, marmalade, amur, tank, silks, abidjan,
# Nearest to animals: primates, suborder, sorghum, argumentum, mongoloid, food, explorers, ponies,
# Nearest to san: diego, sioux, schenectady, delgado, tucson, ducks, imlay, pero,
# Epoch 8/10 Iteration: 16100 Avg. Training loss: 3.9347 0.0662 sec/batch
# Epoch 8/10 Iteration: 16200 Avg. Training loss: 3.9487 0.0647 sec/batch
# Epoch 8/10 Iteration: 16300 Avg. Training loss: 3.9644 0.0649 sec/batch
# Epoch 8/10 Iteration: 16400 Avg. Training loss: 3.9412 0.0690 sec/batch
# Epoch 8/10 Iteration: 16500 Avg. Training loss: 3.9012 0.0647 sec/batch
# Epoch 8/10 Iteration: 16600 Avg. Training loss: 3.9572 0.0649 sec/batch
# Epoch 8/10 Iteration: 16700 Avg. Training loss: 3.9571 0.0646 sec/batch
# Epoch 8/10 Iteration: 16800 Avg. Training loss: 3.9859 0.0648 sec/batch
# Epoch 8/10 Iteration: 16900 Avg. Training loss: 3.9542 0.0648 sec/batch
# Epoch 8/10 Iteration: 17000 Avg. Training loss: 3.9641 0.0653 sec/batch
# Nearest to from: of, continuation, ternary, troad, half, regulation, remarque, sulfate,
# Nearest to not: injustice, usage, represent, stitching, elamite, lachish, yin, peremptory,
# Nearest to will: situations, expected, contents, hajj, assuming, roundaboutness, watchman, accountable,
# Nearest to had: was, diagnosed, foretell, after, waal, reassert, his, circulating,
# Nearest to world: champions, framework, protesting, hashim, critique, pigpen, thinkers, imaginative,
# Nearest to some: ncv, derogatory, armenian, conjoined, hands, bishop, hopewell, fsf,
# Nearest to this: a, heapsort, qualitatively, pre, puts, below, abydos, calendars,
# Nearest to use: suitcase, unvoiced, marks, nokia, some, warn, antecedent, buffers,
# Nearest to engineering: graduated, campus, magnetometer, instituting, deals, disciplines, engineers, interacts,
# Nearest to taking: envisioned, tetralogy, help, inflows, parable, students, csicop, immature,
# Nearest to road: expressways, lough, railway, syriacs, rail, traffic, beltway, motorway,
# Nearest to hit: brasses, funny, singles, hitter, score, unreleased, let, loopholes,
# Nearest to instance: consider, forged, follows, dexterity, decrypts, subregions, rmb, derose,
# Nearest to heavy: pips, euglenids, reconnaissance, amur, marmalade, tank, ssbauer, silks,
# Nearest to animals: primates, argumentum, suborder, food, ponies, explorers, rinsing, sorghum,
# Nearest to san: diego, sioux, schenectady, delgado, imlay, tucson, chemical, ducks,
# Epoch 8/10 Iteration: 17100 Avg. Training loss: 3.9551 0.0657 sec/batch
# Epoch 8/10 Iteration: 17200 Avg. Training loss: 3.9861 0.0666 sec/batch
# Epoch 8/10 Iteration: 17300 Avg. Training loss: 3.9672 0.0650 sec/batch
# Epoch 8/10 Iteration: 17400 Avg. Training loss: 3.9527 0.0658 sec/batch
# Epoch 8/10 Iteration: 17500 Avg. Training loss: 3.9537 0.0658 sec/batch
# Epoch 8/10 Iteration: 17600 Avg. Training loss: 4.0038 0.0668 sec/batch
# Epoch 8/10 Iteration: 17700 Avg. Training loss: 4.0115 0.0663 sec/batch
# Epoch 8/10 Iteration: 17800 Avg. Training loss: 3.9088 0.0661 sec/batch
# Epoch 8/10 Iteration: 17900 Avg. Training loss: 3.9360 0.0664 sec/batch
# Epoch 8/10 Iteration: 18000 Avg. Training loss: 3.9685 0.0660 sec/batch
# Nearest to from: continuation, of, half, troad, ternary, regulation, sulfate, transceiver,
# Nearest to not: injustice, represent, peremptory, capitalization, any, stitching, usage, forwarded,
# Nearest to will: situations, contents, hajj, expected, roundaboutness, watchman, assuming, everlasting,
# Nearest to had: was, after, diagnosed, reassert, circulating, foretell, scapegoat, waal,
# Nearest to world: champions, protesting, framework, hashim, vienna, critique, struggles, dresden,
# Nearest to some: ncv, derogatory, cases, conjoined, hands, armenian, fsf, use,
# Nearest to this: a, qualitatively, heapsort, puts, abydos, taker, calendars, below,
# Nearest to use: suitcase, unvoiced, marks, some, antecedent, strictly, angina, recreations,
# Nearest to engineering: graduated, gluconeogenesis, deals, disciplines, instituting, campus, sciences, magnetometer,
# Nearest to taking: envisioned, tetralogy, inflows, parable, students, help, csicop, lempira,
# Nearest to road: expressways, lough, railway, syriacs, rail, traffic, flagging, routes,
# Nearest to hit: brasses, funny, hitter, singles, pmrc, score, loopholes, otello,
# Nearest to instance: consider, forged, dexterity, follows, decrypts, subregions, derose, infante,
# Nearest to heavy: pips, euglenids, marmalade, reconnaissance, amur, tank, abidjan, ssbauer,
# Nearest to animals: primates, suborder, ponies, explorers, argumentum, rinsing, sorghum, mongoloid,
# Nearest to san: diego, sioux, schenectady, tucson, delgado, gabriel, imlay, ducks,
# Epoch 9/10 Iteration: 18100 Avg. Training loss: 3.9391 0.0241 sec/batch
# Epoch 9/10 Iteration: 18200 Avg. Training loss: 3.9448 0.0665 sec/batch
# Epoch 9/10 Iteration: 18300 Avg. Training loss: 3.9653 0.0668 sec/batch
# Epoch 9/10 Iteration: 18400 Avg. Training loss: 3.9412 0.0670 sec/batch
# Epoch 9/10 Iteration: 18500 Avg. Training loss: 3.9560 0.0663 sec/batch
# Epoch 9/10 Iteration: 18600 Avg. Training loss: 3.9312 0.0664 sec/batch
# Epoch 9/10 Iteration: 18700 Avg. Training loss: 3.8648 0.0665 sec/batch
# Epoch 9/10 Iteration: 18800 Avg. Training loss: 3.8856 0.0665 sec/batch
# Epoch 9/10 Iteration: 18900 Avg. Training loss: 3.9160 0.0651 sec/batch
# Epoch 9/10 Iteration: 19000 Avg. Training loss: 3.9394 0.0655 sec/batch
# Nearest to from: continuation, of, troad, half, sulfate, ternary, mauritians, transceiver,
# Nearest to not: any, er, injustice, be, stitching, represent, peremptory, usage,
# Nearest to will: contents, situations, expected, hajj, assuming, everlasting, expect, roundaboutness,
# Nearest to had: was, after, diagnosed, dungy, amazons, foretell, cracked, waal,
# Nearest to world: champions, framework, vienna, protesting, market, hashim, thinkers, finished,
# Nearest to some: ncv, use, derogatory, cases, hands, conjoined, armenian, excellent,
# Nearest to this: a, qualitatively, heapsort, pre, below, puts, calendars, it,
# Nearest to use: suitcase, some, marks, unvoiced, nokia, strictly, antecedent, angina,
# Nearest to engineering: graduated, campus, disciplines, sciences, engineers, doctoral, instituting, magnetometer,
# Nearest to taking: envisioned, tetralogy, inflows, parable, students, help, lempira, csicop,
# Nearest to road: expressways, lough, railway, syriacs, rail, traffic, routes, beltway,
# Nearest to hit: brasses, funny, hitter, singles, score, let, ps, unreleased,
# Nearest to instance: consider, forged, dexterity, follows, decrypts, subregions, rmb, does,
# Nearest to heavy: pips, euglenids, reconnaissance, marmalade, silks, tank, abidjan, amur,
# Nearest to animals: primates, ponies, explorers, suborder, argumentum, jovian, food, rinsing,
# Nearest to san: diego, sioux, schenectady, delgado, gabriel, chemical, tucson, imlay,
# Epoch 9/10 Iteration: 19100 Avg. Training loss: 3.9092 0.0661 sec/batch
# Epoch 9/10 Iteration: 19200 Avg. Training loss: 3.9307 0.0648 sec/batch
# Epoch 9/10 Iteration: 19300 Avg. Training loss: 3.9274 0.0665 sec/batch
# Epoch 9/10 Iteration: 19400 Avg. Training loss: 3.9312 0.0668 sec/batch
# Epoch 9/10 Iteration: 19500 Avg. Training loss: 3.9246 0.0662 sec/batch
# Epoch 9/10 Iteration: 19600 Avg. Training loss: 3.9412 0.0665 sec/batch
# Epoch 9/10 Iteration: 19700 Avg. Training loss: 3.9124 0.0652 sec/batch
# Epoch 9/10 Iteration: 19800 Avg. Training loss: 3.9025 0.0656 sec/batch
# Epoch 9/10 Iteration: 19900 Avg. Training loss: 4.0080 0.0648 sec/batch
# Epoch 9/10 Iteration: 20000 Avg. Training loss: 3.9513 0.0653 sec/batch
# Nearest to from: of, continuation, regulation, half, troad, remarque, becoming, alas,
# Nearest to not: any, injustice, peremptory, overseas, er, appellant, yin, case,
# Nearest to will: hajj, contents, situations, everlasting, expected, roundaboutness, watchman, litters,
# Nearest to had: was, after, diagnosed, scapegoat, cracked, dungy, waal, circulating,
# Nearest to world: vienna, framework, champions, dresden, hashim, protesting, proponent, struggles,
# Nearest to some: derogatory, armenian, ncv, cases, hands, conjoined, use, a,
# Nearest to this: a, qualitatively, the, pre, abydos, urbino, below, out,
# Nearest to use: marks, suitcase, unvoiced, antecedent, some, toshiba, buffers, nokia,
# Nearest to engineering: graduated, engineers, instituting, disciplines, doctoral, campus, gluconeogenesis, sciences,
# Nearest to taking: inflows, parable, envisioned, tetralogy, students, csicop, lempira, questioned,
# Nearest to road: expressways, lough, railway, syriacs, traffic, rail, beltway, motorway,
# Nearest to hit: brasses, funny, singles, hitter, pmrc, unreleased, otello, armenia,
# Nearest to instance: consider, forged, follows, dexterity, infante, rmb, decrypts, does,
# Nearest to heavy: pips, euglenids, reconnaissance, marmalade, abidjan, ssbauer, amur, tank,
# Nearest to animals: primates, suborder, ponies, jovian, food, argumentum, rinsing, explorers,
# Nearest to san: diego, sioux, schenectady, chemical, gabriel, delgado, friendship, imlay,
# Epoch 9/10 Iteration: 20100 Avg. Training loss: 3.9167 0.0660 sec/batch
# Epoch 9/10 Iteration: 20200 Avg. Training loss: 3.9088 0.0656 sec/batch
# Epoch 9/10 Iteration: 20300 Avg. Training loss: 3.9376 0.0653 sec/batch
# Epoch 10/10 Iteration: 20400 Avg. Training loss: 3.9381 0.0510 sec/batch
# Epoch 10/10 Iteration: 20500 Avg. Training loss: 3.9019 0.0654 sec/batch
# Epoch 10/10 Iteration: 20600 Avg. Training loss: 3.8899 0.0653 sec/batch
# Epoch 10/10 Iteration: 20700 Avg. Training loss: 3.8952 0.0651 sec/batch
# Epoch 10/10 Iteration: 20800 Avg. Training loss: 3.9199 0.0652 sec/batch
# Epoch 10/10 Iteration: 20900 Avg. Training loss: 3.8718 0.0658 sec/batch
# Epoch 10/10 Iteration: 21000 Avg. Training loss: 3.8627 0.0650 sec/batch
# Nearest to from: of, continuation, the, to, troad, in, and, half,
# Nearest to not: er, yin, injustice, peremptory, represent, inseparable, any, opener,
# Nearest to will: situations, hajj, contents, everlasting, roundaboutness, expected, god, cooker,
# Nearest to had: was, after, diagnosed, scapegoat, foretell, amazons, reassert, plainly,
# Nearest to world: vienna, framework, champions, hashim, struggles, proponent, protesting, market,
# Nearest to some: use, although, ncv, a, derogatory, conjoined, other, cases,
# Nearest to this: a, the, that, qualitatively, out, pre, calendars, it,
# Nearest to use: some, suitcase, marks, unvoiced, strictly, antecedent, toshiba, pathogenic,
# Nearest to engineering: graduated, engineers, instituting, disciplines, campus, doctoral, gluconeogenesis, deals,
# Nearest to taking: inflows, parable, envisioned, tetralogy, students, barajas, lempira, canc,
# Nearest to road: expressways, lough, traffic, syriacs, railway, rail, beltway, highway,
# Nearest to hit: brasses, hitter, funny, singles, score, loopholes, pmrc, unreleased,
# Nearest to instance: consider, follows, forged, subregions, dexterity, does, demetrius, decrypts,
# Nearest to heavy: pips, euglenids, reconnaissance, abidjan, marmalade, tank, amur, ssbauer,
# Nearest to animals: primates, suborder, ponies, food, explorers, jovian, argumentum, squid,
# Nearest to san: diego, sioux, gabriel, schenectady, tucson, jose, friendship, chemical,
# Epoch 10/10 Iteration: 21100 Avg. Training loss: 3.8851 0.0659 sec/batch
# Epoch 10/10 Iteration: 21200 Avg. Training loss: 3.8859 0.0650 sec/batch
# Epoch 10/10 Iteration: 21300 Avg. Training loss: 3.9170 0.0650 sec/batch
# Epoch 10/10 Iteration: 21400 Avg. Training loss: 3.8753 0.0650 sec/batch
# Epoch 10/10 Iteration: 21500 Avg. Training loss: 3.8928 0.0654 sec/batch
# Epoch 10/10 Iteration: 21600 Avg. Training loss: 3.9132 0.0651 sec/batch
# Epoch 10/10 Iteration: 21700 Avg. Training loss: 3.9096 0.0652 sec/batch
# Epoch 10/10 Iteration: 21800 Avg. Training loss: 3.9269 0.0654 sec/batch
# Epoch 10/10 Iteration: 21900 Avg. Training loss: 3.8884 0.0660 sec/batch
# Epoch 10/10 Iteration: 22000 Avg. Training loss: 3.8825 0.0664 sec/batch
# Nearest to from: of, continuation, the, in, and, to, troad, half,
# Nearest to not: any, be, er, this, or, represent, heterozygote, yin,
# Nearest to will: situations, contents, hajj, everlasting, roundaboutness, expected, declare, assuming,
# Nearest to had: was, after, scapegoat, foretell, diagnosed, waal, reassert, under,
# Nearest to world: vienna, framework, champions, protesting, hashim, struggles, dresden, western,
# Nearest to some: a, use, although, cases, for, derogatory, ncv, conjoined,
# Nearest to this: a, the, that, qualitatively, to, not, pre, out,
# Nearest to use: some, marks, suitcase, antecedent, strictly, unvoiced, unused, unam,
# Nearest to engineering: graduated, engineers, instituting, deals, disciplines, gluconeogenesis, subdisciplines, doctoral,
# Nearest to taking: inflows, envisioned, parable, students, tetralogy, beni, yetzer, questioned,
# Nearest to road: expressways, lough, traffic, syriacs, railway, rail, beltway, motorway,
# Nearest to hit: brasses, hitter, funny, singles, pmrc, loopholes, armenia, unreleased,
# Nearest to instance: consider, forged, follows, subregions, dexterity, does, decrypts, infante,
# Nearest to heavy: pips, euglenids, reconnaissance, abidjan, ssbauer, marmalade, wfw, tank,
# Nearest to animals: primates, ponies, suborder, food, jovian, argumentum, explorers, squid,
# Nearest to san: diego, sioux, gabriel, chemical, schenectady, friendship, jose, imlay,
# Epoch 10/10 Iteration: 22100 Avg. Training loss: 3.9710 0.0681 sec/batch
# Epoch 10/10 Iteration: 22200 Avg. Training loss: 3.9639 0.0652 sec/batch
# Epoch 10/10 Iteration: 22300 Avg. Training loss: 3.8800 0.0656 sec/batch
# Epoch 10/10 Iteration: 22400 Avg. Training loss: 3.8612 0.0653 sec/batch
# Epoch 10/10 Iteration: 22500 Avg. Training loss: 3.9077 0.0654 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# WARNING:tensorflow:From C:\Program Files\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
t_end = time.perf_counter()
print('Total Time taken: ', t_end-t_start,'seconds')
# Out:
# Total Time taken:  1544.7270804999998 seconds
